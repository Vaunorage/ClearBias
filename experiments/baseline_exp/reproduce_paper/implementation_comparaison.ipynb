# %% [markdown]
# Salut,
#
# Dans le premier volet de notre travail nous évaluons les méthodes de découverte de discrimination.
#
# Les méthodes sont évaluées sur les métriques suivantes :
# -	TSN (Total Sample Number) : Le nombre total d'échantillons générés ou testés lors d'une expérience de test d'équité algorithmique.
# -	DSN (Discriminatory Sample Number) : Le nombre d'échantillons discriminatoires détectés parmi les échantillons testés.
# -	DSS (Discriminatory Sample Search time) : Le temps moyen nécessaire pour générer un échantillon discriminatoire, calculé généralement en divisant le temps total par le nombre d'échantillons discriminatoires trouvés.
# -	SUR (Success Rate) : Le taux de réussite dans la génération d'échantillons discriminatoires, calculé en divisant le nombre d'échantillons discriminatoires (DSN) par le nombre total d'échantillons générés (TSN).
#
# Les méthodes évaluées sont :
# -	Aequitas : Automated directed fairness testing (2018)
# -	EXPGA : Explanation-Guided Fairness Testing through Genetic Algorithm (2022)
# -	SG : Black box fairness testing of machine learning models (2019)
# -	ADF : White-box fairness testing through adversarial sampling (2020)
#
#
#
#
#
# Dans les dernières semaines j’ai travaillé à faire en sorte que l’on génère de la donnée synthétique de qualité pour nos test

# %%
from experiments.baseline_exp.reproduce_paper.reference_exp import ref_data
reference_data = ref_data()
reference_data
# Out:
#    algorithm dataset feature model     TSN     DSN    DSS     SUR
# 0      ExpGA  Census  gender   MLP  491323  141049   0.03  0.2870
# 1      ExpGA  Census     age   MLP   43465   29467   0.12  0.6779
# 2      ExpGA  Census    race   MLP   90303   30171   0.12  0.3341
# 3      ExpGA  Credit  gender   MLP  281130   65009   0.06  0.2312
# 4      ExpGA  Credit     age   MLP   46357   34048   0.11  0.7344
# 5      ExpGA    Bank     age   MLP   46802   27099   0.13  0.5790
# 6   Aequitas  Census  gender   MLP   85629    1797   2.00  0.0210
# 7   Aequitas  Census     age   MLP   12243    1107   3.25  0.0904
# 8   Aequitas  Census    race   MLP   22053     551   6.53  0.0250
# 9   Aequitas  Credit  gender   MLP   38096    1596   2.26  0.0419
# 10  Aequitas  Credit     age   MLP   11756    5146   0.70  0.4377
# 11  Aequitas    Bank     age   MLP   14808    2915   1.23  0.1968
# 12        SG  Census  gender   MLP    7070     871   4.13  0.1231
# 13        SG  Census     age   MLP    4190    1530   2.35  0.3651
# 14        SG  Census    race   MLP    4355     588   6.12  0.1350
# 15        SG  Credit  gender   MLP    7569    1321   2.73  0.1745
# 16        SG  Credit     age   MLP    7699    4659   0.77  0.6050
# 17        SG    Bank     age   MLP    3776    2592   1.39  0.6863
# 18       ADF  Census  gender   MLP  116119   24974   0.14  0.2151
# 19       ADF  Census     age   MLP   40135   21795   0.17  0.5430
# 20       ADF  Census    race   MLP   47296    8097   0.44  0.1712
# 21       ADF  Credit  gender   MLP   62242    8052   0.45  0.1293
# 22       ADF  Credit     age   MLP   21649    5957   0.60  0.2751
# 23       ADF    Bank     age   MLP   27325   11852   0.30  0.4337
# 24     ExpGA  Census  gender    RF  274521  156259   0.02  0.5692
# 25     ExpGA  Census     age    RF   51192   46035   0.08  0.8993
# 26     ExpGA  Census    race    RF   78349   47810   0.08  0.6102
# 27     ExpGA  Credit  gender    RF   20295    4247   0.85  0.2093
# 28     ExpGA  Credit     age    RF   10183    3673   0.98  0.3607
# 29     ExpGA    Bank     age    RF   13284    8885   0.41  0.6699
# 30  Aequitas  Census  gender    RF   56776    1210   2.98  0.0213
# 31  Aequitas  Census     age    RF   21330   13472   0.27  0.6316
# 32  Aequitas  Census    race    RF   29309     362   9.94  0.0124
# 33  Aequitas  Credit  gender    RF    3245     148  24.32  0.0456
# 34  Aequitas  Credit     age    RF     869     153  23.53  0.1760
# 35  Aequitas    Bank     age    RF    3952     941   3.83  0.2381
# 36        SG  Census  gender    RF   10906     595   6.05  0.0546
# 37        SG  Census     age    RF   17490   12441   0.29  0.7150
# 38        SG  Census    race    RF   12572     894   4.03  0.0711
# 39        SG  Credit  gender    RF    7269    2192   1.64  0.3015
# 40        SG  Credit     age    RF    6349    2654   1.36  0.4180
# 41        SG    Bank     age    RF    3871    2530   1.42  0.6536
# 42     ExpGA  Census  gender   SVM  804328  145226   0.02  0.1806
# 43     ExpGA  Census     age   SVM  124816   78064   0.05  0.6254
# 44     ExpGA  Census    race   SVM  226434   78627   0.05  0.3472
# 45     ExpGA  Credit  gender   SVM  118428   47570   0.08  0.4017
# 46     ExpGA  Credit     age   SVM   21058    9377   0.38  0.4453
# 47     ExpGA    Bank     age   SVM   12746   29574   0.12  0.6919
# 48  Aequitas  Census  gender   SVM  109706     386   9.33  0.0035
# 49  Aequitas  Census     age   SVM   81275    2489   1.45  0.0306
# 50  Aequitas  Census    race   SVM   62954     277  13.00  0.0044
# 51  Aequitas  Credit  gender   SVM  152432    3683   0.98  0.0242
# 52  Aequitas  Credit     age   SVM   53344    8419   0.43  0.1578
# 53  Aequitas    Bank     age   SVM   31276      41  87.80  0.0013
# 54        SG  Census  gender   SVM    1119       0    NaN  0.0000
# 55        SG  Census     age   SVM    2998     624   5.77  0.2081
# 56        SG  Census    race   SVM    1141       0    NaN  0.0000
# 57        SG  Credit  gender   SVM    9204    1912   1.88  0.2077
# 58        SG  Credit     age   SVM    7952    1918   1.88  0.2412
# 59        SG    Bank     age   SVM     744     248  14.52  0.3333

# %%
from path import HERE
from pathlib import Path
import sqlite3
import pandas as pd

DB_PATH = Path(HERE.joinpath("experiments/baseline_exp/exp.db"))

conn = sqlite3.connect(DB_PATH)
sql = f"""
SELECT * 
FROM main.paper_reproduction_results
"""
experiments = pd.read_sql(sql, conn)

experiments
# Out:
#      id            timestamp model dataset  feature algorithm     TSN    DSN  \
# 0    85  2025-03-23 14:45:14   MLP   adult  Attr8_T     ExpGA   91650  28777
# 1    86  2025-03-23 14:45:14   MLP   adult  Attr9_T     ExpGA   67110  15116
# 2    87  2025-03-23 14:51:51   MLP   adult  Attr8_T        SG    1414    549
# 3    88  2025-03-23 14:51:51   MLP   adult  Attr9_T        SG    1414     86
# 4    89  2025-03-23 15:05:25   MLP   adult  Attr8_T  Aequitas  988160   7363
# 5    90  2025-03-23 15:05:25   MLP   adult  Attr9_T  Aequitas  247040   1734
# 6    91  2025-03-23 15:17:28   MLP   adult  Attr8_T       ADF   93696  45977
# 7    92  2025-03-23 15:17:28   MLP   adult  Attr9_T       ADF   27012   2614
# 8    93  2025-03-23 16:00:10   MLP   adult  Attr8_T     ExpGA  167405  56828
# 9    94  2025-03-23 16:00:10   MLP   adult  Attr9_T     ExpGA  118902  24932
# 10   95  2025-03-23 16:05:19   MLP   adult  Attr8_T        SG    1414    549
# 11   96  2025-03-23 16:05:19   MLP   adult  Attr9_T        SG    1414     86
# 12   97  2025-03-23 16:17:38   MLP   adult  Attr8_T  Aequitas  988160   7363
# 13   98  2025-03-23 16:17:38   MLP   adult  Attr9_T  Aequitas  247040   1734
# 14   99  2025-03-23 16:28:28   MLP   adult  Attr8_T       ADF   93696  45977
# 15  100  2025-03-23 16:28:28   MLP   adult  Attr9_T       ADF   27012   2614
#
#            DSS       SUR  execution_time
# 0   564.444118  0.313988     1572.235132
# 1   564.444118  0.225242     1572.235132
# 2     0.620000  0.388260      396.736225
# 3     0.620000  0.060820      396.736225
# 4     0.086859  0.007451      814.909656
# 5     0.086859  0.007019      814.909656
# 6     0.014825  0.490704      722.975971
# 7     0.014825  0.096772      722.975971
# 8   502.846231  0.339464     2561.482530
# 9   502.846231  0.209685     2561.482530
# 10    0.480000  0.388260      308.872668
# 11    0.480000  0.060820      308.872668
# 12    0.078913  0.007451      739.209410
# 13    0.078913  0.007019      739.209410
# 14    0.013351  0.490704      650.248398
# 15    0.013351  0.096772      650.248398

# %%
# Replace values where condition is met
experiments.loc[experiments['dataset'] == 'adult', 'dataset'] = 'Census'
experiments.loc[experiments['dataset'] == 'credit', 'dataset'] = 'Credit'
experiments.loc[experiments['dataset'] == 'bank', 'dataset'] = 'Bank'

experiments.loc[experiments['algorithm'] == 'EXPGA', 'algorithm'] = 'ExpGA'
experiments.loc[experiments['algorithm'] == 'EXPGA', 'algorithm'] = 'ExpGA'

experiments.loc[(experiments['feature'] == 'Attr8_T') & (experiments['dataset'] == 'Census'), 'feature'] = 'gender'
experiments.loc[(experiments['feature'] == 'Attr9_T') & (experiments['dataset'] == 'Census'), 'feature'] = 'race'

experiments.loc[(experiments['feature'] == 'Attr8_T') & (experiments['dataset'] == 'Credit'), 'feature'] = 'gender'
experiments.loc[(experiments['feature'] == 'Attr12_T') & (experiments['dataset'] == 'Credit'), 'feature'] = 'age'

experiments.loc[(experiments['feature'] == 'Attr2_T') & (experiments['dataset'] == 'Bank'), 'feature'] = 'marital'
experiments.loc[(experiments['feature'] == 'Attr3_T') & (experiments['dataset'] == 'Bank'), 'feature'] = 'education'

# %%
experiments
# Out:
#      id            timestamp model dataset feature algorithm     TSN    DSN  \
# 0    85  2025-03-23 14:45:14   MLP  Census  gender     ExpGA   91650  28777
# 1    86  2025-03-23 14:45:14   MLP  Census    race     ExpGA   67110  15116
# 2    87  2025-03-23 14:51:51   MLP  Census  gender        SG    1414    549
# 3    88  2025-03-23 14:51:51   MLP  Census    race        SG    1414     86
# 4    89  2025-03-23 15:05:25   MLP  Census  gender  Aequitas  988160   7363
# 5    90  2025-03-23 15:05:25   MLP  Census    race  Aequitas  247040   1734
# 6    91  2025-03-23 15:17:28   MLP  Census  gender       ADF   93696  45977
# 7    92  2025-03-23 15:17:28   MLP  Census    race       ADF   27012   2614
# 8    93  2025-03-23 16:00:10   MLP  Census  gender     ExpGA  167405  56828
# 9    94  2025-03-23 16:00:10   MLP  Census    race     ExpGA  118902  24932
# 10   95  2025-03-23 16:05:19   MLP  Census  gender        SG    1414    549
# 11   96  2025-03-23 16:05:19   MLP  Census    race        SG    1414     86
# 12   97  2025-03-23 16:17:38   MLP  Census  gender  Aequitas  988160   7363
# 13   98  2025-03-23 16:17:38   MLP  Census    race  Aequitas  247040   1734
# 14   99  2025-03-23 16:28:28   MLP  Census  gender       ADF   93696  45977
# 15  100  2025-03-23 16:28:28   MLP  Census    race       ADF   27012   2614
#
#            DSS       SUR  execution_time
# 0   564.444118  0.313988     1572.235132
# 1   564.444118  0.225242     1572.235132
# 2     0.620000  0.388260      396.736225
# 3     0.620000  0.060820      396.736225
# 4     0.086859  0.007451      814.909656
# 5     0.086859  0.007019      814.909656
# 6     0.014825  0.490704      722.975971
# 7     0.014825  0.096772      722.975971
# 8   502.846231  0.339464     2561.482530
# 9   502.846231  0.209685     2561.482530
# 10    0.480000  0.388260      308.872668
# 11    0.480000  0.060820      308.872668
# 12    0.078913  0.007451      739.209410
# 13    0.078913  0.007019      739.209410
# 14    0.013351  0.490704      650.248398
# 15    0.013351  0.096772      650.248398

# %%
results = []
for i, el in reference_data.iterrows():
    key = ((experiments['feature'] == el['feature']) &
           (experiments['dataset'] == el['dataset']) &
           (experiments['model'] == el['model']) &
           (experiments['algorithm'] == el['algorithm']))
    res = pd.DataFrame(
        {'feature': [el['feature']], 'dataset': [el['dataset']], 'model': [el['model']],
         'algorithm': [el['algorithm']]})
    if key.any():
        experiments_df = experiments[key][['TSN', 'DSN', 'DSS', 'SUR']].mean()
        res['ref_TSN'] = el['TSN']
        res['TSN'] = experiments_df['TSN']
        res['ref_DSN'] = el['DSN']
        res['DSN'] = experiments_df['DSN']
        res['ref_DSS'] = el['DSS']
        res['DSS'] = experiments_df['DSS']
        res['ref_SUR'] = el['SUR']
        res['SUR'] = experiments_df['SUR']
    else:
        res['ref_TSN'] = None
        res['TSN'] = None
        res['ref_DSN'] = None
        res['DSN'] = None
        res['ref_DSS'] = None
        res['DSS'] = None
        res['ref_SUR'] = None
        res['SUR'] = None
    results.append(res)
    
results = pd.concat(results)
results
# Out:
# C:\Users\gen06917\AppData\Local\Temp\ipykernel_31076\3575888769.py:31: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results = pd.concat(results)
#   feature dataset model algorithm ref_TSN       TSN ref_DSN      DSN  ref_DSS  \
# 0  gender  Census   MLP     ExpGA  491323  129527.5  141049  42802.5     0.03
# 0     age  Census   MLP     ExpGA    None       NaN    None      NaN      NaN
# 0    race  Census   MLP     ExpGA   90303   93006.0   30171  20024.0     0.12
# 0  gender  Credit   MLP     ExpGA    None       NaN    None      NaN      NaN
# 0     age  Credit   MLP     ExpGA    None       NaN    None      NaN      NaN
# 0     age    Bank   MLP     ExpGA    None       NaN    None      NaN      NaN
# 0  gender  Census   MLP  Aequitas   85629  988160.0    1797   7363.0     2.00
# 0     age  Census   MLP  Aequitas    None       NaN    None      NaN      NaN
# 0    race  Census   MLP  Aequitas   22053  247040.0     551   1734.0     6.53
# 0  gender  Credit   MLP  Aequitas    None       NaN    None      NaN      NaN
# 0     age  Credit   MLP  Aequitas    None       NaN    None      NaN      NaN
# 0     age    Bank   MLP  Aequitas    None       NaN    None      NaN      NaN
# 0  gender  Census   MLP        SG    7070    1414.0     871    549.0     4.13
# 0     age  Census   MLP        SG    None       NaN    None      NaN      NaN
# 0    race  Census   MLP        SG    4355    1414.0     588     86.0     6.12
# 0  gender  Credit   MLP        SG    None       NaN    None      NaN      NaN
# 0     age  Credit   MLP        SG    None       NaN    None      NaN      NaN
# 0     age    Bank   MLP        SG    None       NaN    None      NaN      NaN
# 0  gender  Census   MLP       ADF  116119   93696.0   24974  45977.0     0.14
# 0     age  Census   MLP       ADF    None       NaN    None      NaN      NaN
# 0    race  Census   MLP       ADF   47296   27012.0    8097   2614.0     0.44
# 0  gender  Credit   MLP       ADF    None       NaN    None      NaN      NaN
# 0     age  Credit   MLP       ADF    None       NaN    None      NaN      NaN
# 0     age    Bank   MLP       ADF    None       NaN    None      NaN      NaN
# 0  gender  Census    RF     ExpGA    None       NaN    None      NaN      NaN
# 0     age  Census    RF     ExpGA    None       NaN    None      NaN      NaN
# 0    race  Census    RF     ExpGA    None       NaN    None      NaN      NaN
# 0  gender  Credit    RF     ExpGA    None       NaN    None      NaN      NaN
# 0     age  Credit    RF     ExpGA    None       NaN    None      NaN      NaN
# 0     age    Bank    RF     ExpGA    None       NaN    None      NaN      NaN
# 0  gender  Census    RF  Aequitas    None       NaN    None      NaN      NaN
# 0     age  Census    RF  Aequitas    None       NaN    None      NaN      NaN
# 0    race  Census    RF  Aequitas    None       NaN    None      NaN      NaN
# 0  gender  Credit    RF  Aequitas    None       NaN    None      NaN      NaN
# 0     age  Credit    RF  Aequitas    None       NaN    None      NaN      NaN
# 0     age    Bank    RF  Aequitas    None       NaN    None      NaN      NaN
# 0  gender  Census    RF        SG    None       NaN    None      NaN      NaN
# 0     age  Census    RF        SG    None       NaN    None      NaN      NaN
# 0    race  Census    RF        SG    None       NaN    None      NaN      NaN
# 0  gender  Credit    RF        SG    None       NaN    None      NaN      NaN
# 0     age  Credit    RF        SG    None       NaN    None      NaN      NaN
# 0     age    Bank    RF        SG    None       NaN    None      NaN      NaN
# 0  gender  Census   SVM     ExpGA    None       NaN    None      NaN      NaN
# 0     age  Census   SVM     ExpGA    None       NaN    None      NaN      NaN
# 0    race  Census   SVM     ExpGA    None       NaN    None      NaN      NaN
# 0  gender  Credit   SVM     ExpGA    None       NaN    None      NaN      NaN
# 0     age  Credit   SVM     ExpGA    None       NaN    None      NaN      NaN
# 0     age    Bank   SVM     ExpGA    None       NaN    None      NaN      NaN
# 0  gender  Census   SVM  Aequitas    None       NaN    None      NaN      NaN
# 0     age  Census   SVM  Aequitas    None       NaN    None      NaN      NaN
# 0    race  Census   SVM  Aequitas    None       NaN    None      NaN      NaN
# 0  gender  Credit   SVM  Aequitas    None       NaN    None      NaN      NaN
# 0     age  Credit   SVM  Aequitas    None       NaN    None      NaN      NaN
# 0     age    Bank   SVM  Aequitas    None       NaN    None      NaN      NaN
# 0  gender  Census   SVM        SG    None       NaN    None      NaN      NaN
# 0     age  Census   SVM        SG    None       NaN    None      NaN      NaN
# 0    race  Census   SVM        SG    None       NaN    None      NaN      NaN
# 0  gender  Credit   SVM        SG    None       NaN    None      NaN      NaN
# 0     age  Credit   SVM        SG    None       NaN    None      NaN      NaN
# 0     age    Bank   SVM        SG    None       NaN    None      NaN      NaN
#
#           DSS  ref_SUR       SUR
# 0  533.645174   0.2870  0.326726
# 0         NaN      NaN       NaN
# 0  533.645174   0.3341  0.217464
# 0         NaN      NaN       NaN
# 0         NaN      NaN       NaN
# 0         NaN      NaN       NaN
# 0    0.082886   0.0210  0.007451
# 0         NaN      NaN       NaN
# 0    0.082886   0.0250  0.007019
# 0         NaN      NaN       NaN
# 0         NaN      NaN       NaN
# 0         NaN      NaN       NaN
# 0    0.550000   0.1231  0.388260
# 0         NaN      NaN       NaN
# 0    0.550000   0.1350  0.060820
# 0         NaN      NaN       NaN
# 0         NaN      NaN       NaN
# 0         NaN      NaN       NaN
# 0    0.014088   0.2151  0.490704
# 0         NaN      NaN       NaN
# 0    0.014088   0.1712  0.096772
# 0         NaN      NaN       NaN
# 0         NaN      NaN       NaN
# 0         NaN      NaN       NaN
# 0         NaN      NaN       NaN
# 0         NaN      NaN       NaN
# 0         NaN      NaN       NaN
# 0         NaN      NaN       NaN
# 0         NaN      NaN       NaN
# 0         NaN      NaN       NaN
# 0         NaN      NaN       NaN
# 0         NaN      NaN       NaN
# 0         NaN      NaN       NaN
# 0         NaN      NaN       NaN
# 0         NaN      NaN       NaN
# 0         NaN      NaN       NaN
# 0         NaN      NaN       NaN
# 0         NaN      NaN       NaN
# 0         NaN      NaN       NaN
# 0         NaN      NaN       NaN
# 0         NaN      NaN       NaN
# 0         NaN      NaN       NaN
# 0         NaN      NaN       NaN
# 0         NaN      NaN       NaN
# 0         NaN      NaN       NaN
# 0         NaN      NaN       NaN
# 0         NaN      NaN       NaN
# 0         NaN      NaN       NaN
# 0         NaN      NaN       NaN
# 0         NaN      NaN       NaN
# 0         NaN      NaN       NaN
# 0         NaN      NaN       NaN
# 0         NaN      NaN       NaN
# 0         NaN      NaN       NaN
# 0         NaN      NaN       NaN
# 0         NaN      NaN       NaN
# 0         NaN      NaN       NaN
# 0         NaN      NaN       NaN
# 0         NaN      NaN       NaN
# 0         NaN      NaN       NaN
